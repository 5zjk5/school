# %%
import pandas as pd 
from collections import Counter

# %%
df1 = pd.read_csv('../data/school.csv',encoding='gbk')
df2 = pd.read_csv('../data/professional.csv',encoding='gbk')

# %%
display(df1.head(1))
display(df2.head(1))
# Out:
#              学校  省份    城市                               地址    水平层次 办学类别 办学类型  \
# 0  河北轨道运输职业技术学院  河北  石家庄市  河北省石家庄市经济技术开发区赣江路9号,石家庄市宁安路189号  专科（高职）  理工类   公办
#
#   985 211  双一流   归属                                        开设专业链接
# 0   否   否  NaN  河北省  https://gkcx.eol.cn/school/2858/professional
#              学校        专业类别      专业名称 国家特色专业
# 0  河北轨道运输职业技术学院  测绘地理信息类(专)  测绘地理信息技术    NaN

# %% [markdown]
# # 大学省份分布，热力地图

# %%
province = list(df1['省份'])
p_v = dict(Counter(province))
p = list(p_v.keys())
v = list(p_v.values())

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker
from pyecharts.globals import ThemeType

c = (
    Map(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
    .add("", [list(z) for z in zip(p,v)], "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="高校分布地区"),
        visualmap_opts=opts.VisualMapOpts(max_=200, is_piecewise=True),
    )
)
c.render('../output/高校分布地区.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="8cddca5abaa64a8a97a57d46c68f1014" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china', 'essos'], function(echarts) {
#                 var chart_8cddca5abaa64a8a97a57d46c68f1014 = echarts.init(
#                     document.getElementById('8cddca5abaa64a8a97a57d46c68f1014'), 'essos', {renderer: 'canvas'});
#                 var option_8cddca5abaa64a8a97a57d46c68f1014 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 126
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 90
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 137
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 134
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 102
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 163
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 129
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 174
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 73
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 111
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 160
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 158
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 104
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 110
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 108
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 81
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 82
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 128
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 85
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 85
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 5
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u9ad8\u6821\u5206\u5e03\u5730\u533a",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_8cddca5abaa64a8a97a57d46c68f1014.setOption(option_8cddca5abaa64a8a97a57d46c68f1014);
#         });
#     </script>

# %% [markdown]
# # 本科、专科占比，圆环图

# %%
level = df1['水平层次'].value_counts().reset_index()
l = list(level['index'])
v = list(level['水平层次'])

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

c = (
    Pie(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
    .add(
        "",
        [list(z) for z in zip(l,v)],
        radius=["40%", "75%"],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="本/专科占比"),
        legend_opts=opts.LegendOpts(orient="vertical", pos_top="15%", pos_left="2%"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
c.render('../output/本专科占比.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="11ee390590b24f1fb9260b383b90a600" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'essos'], function(echarts) {
#                 var chart_11ee390590b24f1fb9260b383b90a600 = echarts.init(
#                     document.getElementById('11ee390590b24f1fb9260b383b90a600'), 'essos', {renderer: 'canvas'});
#                 var option_11ee390590b24f1fb9260b383b90a600 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u4e13\u79d1\uff08\u9ad8\u804c\uff09",
#                     "value": 1499
#                 },
#                 {
#                     "name": "\u666e\u901a\u672c\u79d1",
#                     "value": 1357
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e13\u79d1\uff08\u9ad8\u804c\uff09",
#                 "\u666e\u901a\u672c\u79d1"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u672c/\u4e13\u79d1\u5360\u6bd4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_11ee390590b24f1fb9260b383b90a600.setOption(option_11ee390590b24f1fb9260b383b90a600);
#         });
#     </script>

# %% [markdown]
# # 办学类别各个占比，饼图

# %%
level = df1['办学类别'].value_counts().reset_index()
l = list(level['index'])
v = list(level['办学类别'])

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

c = (
    Pie(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
    .add(
        "",
        [list(z) for z in zip(l,v)],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="办学类别占比"),
        legend_opts=opts.LegendOpts(orient="vertical", pos_top="15%", pos_left="2%"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
c.render('../output/办学类别占比.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="adc4c1030ff54883bc429f637edaadbe" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'essos'], function(echarts) {
#                 var chart_adc4c1030ff54883bc429f637edaadbe = echarts.init(
#                     document.getElementById('adc4c1030ff54883bc429f637edaadbe'), 'essos', {renderer: 'canvas'});
#                 var option_adc4c1030ff54883bc429f637edaadbe = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7406\u5de5\u7c7b",
#                     "value": 865
#                 },
#                 {
#                     "name": "\u7efc\u5408\u7c7b",
#                     "value": 828
#                 },
#                 {
#                     "name": "\u5e08\u8303\u7c7b",
#                     "value": 242
#                 },
#                 {
#                     "name": "\u8d22\u7ecf\u7c7b",
#                     "value": 216
#                 },
#                 {
#                     "name": "\u533b\u836f\u7c7b",
#                     "value": 216
#                 },
#                 {
#                     "name": "\u827a\u672f\u7c7b",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u519c\u6797\u7c7b",
#                     "value": 87
#                 },
#                 {
#                     "name": "\u653f\u6cd5\u7c7b",
#                     "value": 68
#                 },
#                 {
#                     "name": "\u519b\u4e8b\u7c7b",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u8bed\u8a00\u7c7b",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u4f53\u80b2\u7c7b",
#                     "value": 35
#                 },
#                 {
#                     "name": "\u6c11\u65cf\u7c7b",
#                     "value": 15
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7406\u5de5\u7c7b",
#                 "\u7efc\u5408\u7c7b",
#                 "\u5e08\u8303\u7c7b",
#                 "\u8d22\u7ecf\u7c7b",
#                 "\u533b\u836f\u7c7b",
#                 "\u827a\u672f\u7c7b",
#                 "\u519c\u6797\u7c7b",
#                 "\u653f\u6cd5\u7c7b",
#                 "\u519b\u4e8b\u7c7b",
#                 "\u5176\u4ed6",
#                 "\u8bed\u8a00\u7c7b",
#                 "\u4f53\u80b2\u7c7b",
#                 "\u6c11\u65cf\u7c7b"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u529e\u5b66\u7c7b\u522b\u5360\u6bd4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_adc4c1030ff54883bc429f637edaadbe.setOption(option_adc4c1030ff54883bc429f637edaadbe);
#         });
#     </script>

# %% [markdown]
# # 普通，985,211，双一流数量对比，柱状图

# %%
s_985 = df1[df1['985'] == '是'].shape[0]
s_211 = df1[df1['211'] == '是'].shape[0]
s_yiliu = int(df1['双一流'].value_counts().values[0])

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
    .add_xaxis(['985','211','双一流'])
    .add_yaxis("",[s_985,s_211,s_yiliu])
    .set_global_opts(title_opts=opts.TitleOpts(title="重点大学数"))

)
c.render('../output/重点大学数.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="80746537bb4e45a6ba3f22ec915295e6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'essos'], function(echarts) {
#                 var chart_80746537bb4e45a6ba3f22ec915295e6 = echarts.init(
#                     document.getElementById('80746537bb4e45a6ba3f22ec915295e6'), 'essos', {renderer: 'canvas'});
#                 var option_80746537bb4e45a6ba3f22ec915295e6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 46,
#                 126,
#                 148
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "985",
#                 "211",
#                 "\u53cc\u4e00\u6d41"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u91cd\u70b9\u5927\u5b66\u6570",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_80746537bb4e45a6ba3f22ec915295e6.setOption(option_80746537bb4e45a6ba3f22ec915295e6);
#         });
#     </script>

# %% [markdown]
# # 985,211，双一流主要分布在哪里，条形图

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Timeline
from pyecharts.faker import Faker

tl = Timeline(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
for i in ['985','211','双一流']:
    p_v = df1[df1[i] == '是']
    p_v = p_v['省份'].value_counts().reset_index()[:10]
    p = list(p_v['index'])[::-1]
    v = list(p_v['省份'])[::-1]
    bar = (
        Bar(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
        .add_xaxis(p)
        .add_yaxis("数量",v, label_opts=opts.LabelOpts(position="right"))
        .reversal_axis()
        .set_global_opts(
            title_opts=opts.TitleOpts("重点大学分布轮播图".format(i))
        )
    )
    tl.add(bar, "{}".format(i))
tl.render('../output/重点大学分布.html')
tl.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\composite_charts\timeline.py:12: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="dd376240317847149850809be0c80737" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'essos'], function(echarts) {
#                 var chart_dd376240317847149850809be0c80737 = echarts.init(
#                     document.getElementById('dd376240317847149850809be0c80737'), 'essos', {renderer: 'canvas'});
#                 var option_dd376240317847149850809be0c80737 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "\u6570\u91cf",
#                 "legendHoverLink": true,
#                 "data": [
#                     4,
#                     5,
#                     6,
#                     6,
#                     7,
#                     7,
#                     9,
#                     14,
#                     16,
#                     35
#                 ],
#                 "showBackground": false,
#                 "barMinHeight": 0,
#                 "barCategoryGap": "20%",
#                 "barGap": "30%",
#                 "large": false,
#                 "largeThreshold": 400,
#                 "seriesLayoutBy": "column",
#                 "datasetIndex": 0,
#                 "clip": true,
#                 "zlevel": 0,
#                 "z": 2,
#                 "label": {
#                     "show": true,
#                     "position": "right",
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "985",
#                 "211",
#                 "\u53cc\u4e00\u6d41"
#             ]
#         },
#         "xAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 }
#             }
#         ],
#         "yAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\u9ed1\u9f99\u6c5f",
#                     "\u5c71\u4e1c",
#                     "\u5e7f\u4e1c",
#                     "\u5929\u6d25",
#                     "\u6e56\u5317",
#                     "\u9655\u897f",
#                     "\u56db\u5ddd",
#                     "\u4e0a\u6d77",
#                     "\u6c5f\u82cf",
#                     "\u5317\u4eac"
#                 ]
#             }
#         ]
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u6570\u91cf"
#                     ],
#                     "selected": {
#                         "\u6570\u91cf": true
#                     },
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "bar",
#                     "name": "\u6570\u91cf",
#                     "legendHoverLink": true,
#                     "data": [
#                         2,
#                         2,
#                         2,
#                         3,
#                         3,
#                         3,
#                         3,
#                         4,
#                         5,
#                         9
#                     ],
#                     "showBackground": false,
#                     "barMinHeight": 0,
#                     "barCategoryGap": "20%",
#                     "barGap": "30%",
#                     "large": false,
#                     "largeThreshold": 400,
#                     "seriesLayoutBy": "column",
#                     "datasetIndex": 0,
#                     "clip": true,
#                     "zlevel": 0,
#                     "z": 2,
#                     "label": {
#                         "show": true,
#                         "position": "right",
#                         "margin": 8
#                     }
#                 }
#             ],
#             "xAxis": [
#                 {
#                     "show": true,
#                     "scale": false,
#                     "nameLocation": "end",
#                     "nameGap": 15,
#                     "gridIndex": 0,
#                     "inverse": false,
#                     "offset": 0,
#                     "splitNumber": 5,
#                     "minInterval": 0,
#                     "splitLine": {
#                         "show": false,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "solid"
#                         }
#                     }
#                 }
#             ],
#             "yAxis": [
#                 {
#                     "show": true,
#                     "scale": false,
#                     "nameLocation": "end",
#                     "nameGap": 15,
#                     "gridIndex": 0,
#                     "inverse": false,
#                     "offset": 0,
#                     "splitNumber": 5,
#                     "minInterval": 0,
#                     "splitLine": {
#                         "show": false,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "solid"
#                         }
#                     },
#                     "data": [
#                         "\u5929\u6d25",
#                         "\u8fbd\u5b81",
#                         "\u6c5f\u82cf",
#                         "\u9655\u897f",
#                         "\u6e56\u5357",
#                         "\u56db\u5ddd",
#                         "\u5e7f\u4e1c",
#                         "\u5c71\u4e1c",
#                         "\u4e0a\u6d77",
#                         "\u5317\u4eac"
#                     ]
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "\u91cd\u70b9\u5927\u5b66\u5206\u5e03\u8f6e\u64ad\u56fe",
#                     "padding": 5,
#                     "itemGap": 10
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "

# %% [markdown]
# # 专业类别数量，仪表盘

# %%
pro = df2['专业类别'].value_counts().reset_index().shape[0]
pro
# Out:
# 196

# %% [markdown]
# # 开设专业数前二十的是哪些，柱状图

# %%
pros = df2['专业名称'].value_counts().reset_index()
name = list(pros['index'])[:20]
v = list(pros['专业名称'])[:20]

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
    .add_xaxis(
        name
    )
    .add_yaxis("", v)
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30)),
        title_opts=opts.TitleOpts(title="开设专业top20"),
    )
)
c.render('../output/开设专业top20.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="434738dc95544e74bc046e2f4b8bd8ab" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'essos'], function(echarts) {
#                 var chart_434738dc95544e74bc046e2f4b8bd8ab = echarts.init(
#                     document.getElementById('434738dc95544e74bc046e2f4b8bd8ab'), 'essos', {renderer: 'canvas'});
#                 var option_434738dc95544e74bc046e2f4b8bd8ab = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 1279,
#                 1209,
#                 1053,
#                 1041,
#                 950,
#                 857,
#                 811,
#                 808,
#                 799,
#                 783,
#                 672,
#                 656,
#                 648,
#                 644,
#                 621,
#                 610,
#                 597,
#                 588,
#                 557,
#                 557
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -30,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5e02\u573a\u8425\u9500",
#                 "\u7535\u5b50\u5546\u52a1",
#                 "\u7269\u6d41\u7ba1\u7406",
#                 "\u65c5\u6e38\u7ba1\u7406",
#                 "\u8d22\u52a1\u7ba1\u7406",
#                 "\u4f1a\u8ba1",
#                 "\u56fd\u9645\u7ecf\u6d4e\u4e0e\u8d38\u6613",
#                 "\u8ba1\u7b97\u673a\u79d1\u5b66\u4e0e\u6280\u672f",
#                 "\u5de5\u7a0b\u9020\u4ef7",
#                 "\u82f1\u8bed",
#                 "\u5546\u52a1\u82f1\u8bed",
#                 "\u89c6\u89c9\u4f20\u8fbe\u8bbe\u8ba1",
#                 "\u9152\u5e97\u7ba1\u7406",
#                 "\u73af\u5883\u8bbe\u8ba1",
#                 "\u673a\u7535\u4e00\u4f53\u5316\u6280\u672f",
#                 "\u5b66\u524d\u6559\u80b2",
#                 "\u7535\u5b50\u4fe1\u606f\u5de5\u7a0b",
#                 "\u4f1a\u8ba1\u5b66",
#                 "\u8ba1\u7b97\u673a\u5e94\u7528\u6280\u672f",
#                 "\u4eba\u529b\u8d44\u6e90\u7ba1\u7406"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5f00\u8bbe\u4e13\u4e1atop20",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_434738dc95544e74bc046e2f4b8bd8ab.setOption(option_434738dc95544e74bc046e2f4b8bd8ab);
#         });
#     </script>

# %% [markdown]
# # 这些热门专业主要分布在哪些地区，热力地图

# %%
df3 = pd.merge(df2,df1,how='left',on='学校')
def top20(s):
    if s in name:
        return 1
    else:
        return 0
df3['top20'] = df3['专业名称'].map(top20)
df3 = df3[df3['top20'] == 1]
province = list(df3['省份'])
p_v = dict(Counter(province))
p = list(p_v.keys())
v = list(p_v.values())

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker
from pyecharts.globals import ThemeType

c = (
    Map(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
    .add("", [list(z) for z in zip(p,v)], "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="top20专业分布地区"),
        visualmap_opts=opts.VisualMapOpts(max_=1100, is_piecewise=True),
    )
)
c.render('../output/top20专业分布地区.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="8fe18ff9cc1c49f2920f4ae33197b2be" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china', 'essos'], function(echarts) {
#                 var chart_8fe18ff9cc1c49f2920f4ae33197b2be = echarts.init(
#                     document.getElementById('8fe18ff9cc1c49f2920f4ae33197b2be'), 'essos', {renderer: 'canvas'});
#                 var option_8fe18ff9cc1c49f2920f4ae33197b2be = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 711
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 548
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 755
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 911
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 353
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 716
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 1053
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 338
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 674
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 1048
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 269
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 286
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1074
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 405
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 982
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 594
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 566
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 137
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 696
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 458
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 260
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 375
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 795
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 339
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 504
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 354
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 162
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 234
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 7
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "top20\u4e13\u4e1a\u5206\u5e03\u5730\u533a",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 1100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_8fe18ff9cc1c49f2920f4ae33197b2be.setOption(option_8fe18ff9cc1c49f2920f4ae33197b2be);
#         });
#     </script>

# %% [markdown]
# # 国家特设专业分布在哪些学校

# %%
tese = df2[df2['国家特色专业'] == '是']
tese = tese.groupby('学校').count()['国家特色专业'].reset_index()
tese = tese.sort_values(by='国家特色专业',ascending=False)
school = list(tese['学校'])[:20]
v = list(tese['国家特色专业'])[:20]

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
    .add_xaxis(
        school
    )
    .add_yaxis("", v)
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30)),
        title_opts=opts.TitleOpts(title="特色专业top20"),
    )
)
c.render('../output/特色专业top20.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="6b0c29b8be064dfd9e451b10054d7526" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'essos'], function(echarts) {
#                 var chart_6b0c29b8be064dfd9e451b10054d7526 = echarts.init(
#                     document.getElementById('6b0c29b8be064dfd9e451b10054d7526'), 'essos', {renderer: 'canvas'});
#                 var option_6b0c29b8be064dfd9e451b10054d7526 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 41,
#                 32,
#                 28,
#                 28,
#                 26,
#                 25,
#                 25,
#                 24,
#                 22,
#                 22,
#                 21,
#                 21,
#                 20,
#                 19,
#                 19,
#                 19,
#                 19,
#                 18,
#                 18,
#                 18
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -30,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5317\u4eac\u5927\u5b66",
#                 "\u6d59\u6c5f\u5927\u5b66",
#                 "\u4e0a\u6d77\u4ea4\u901a\u5927\u5b66",
#                 "\u6b66\u6c49\u5927\u5b66",
#                 "\u5409\u6797\u5927\u5b66",
#                 "\u5929\u6d25\u5927\u5b66",
#                 "\u5c71\u4e1c\u5927\u5b66",
#                 "\u534e\u4e2d\u79d1\u6280\u5927\u5b66",
#                 "\u56db\u5ddd\u5927\u5b66",
#                 "\u6e05\u534e\u5927\u5b66",
#                 "\u5927\u8fde\u7406\u5de5\u5927\u5b66",
#                 "\u897f\u5b89\u4ea4\u901a\u5927\u5b66",
#                 "\u5357\u4eac\u5927\u5b66",
#                 "\u897f\u5357\u5927\u5b66",
#                 "\u4e2d\u5357\u5927\u5b66",
#                 "\u54c8\u5c14\u6ee8\u5de5\u4e1a\u5927\u5b66",
#                 "\u5317\u4eac\u5916\u56fd\u8bed\u5927\u5b66",
#                 "\u540c\u6d4e\u5927\u5b66",
#                 "\u534e\u5357\u7406\u5de5\u5927\u5b66",
#                 "\u4e2d\u56fd\u4eba\u6c11\u5927\u5b66"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u7279\u8272\u4e13\u4e1atop20",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_6b0c29b8be064dfd9e451b10054d7526.setOption(option_6b0c29b8be064dfd9e451b10054d7526);
#         });
#     </script>
